# %%
import pandas as pd
from tqdm import tqdm
from datetime import datetime, timedelta
import os
foursquare_nyc_geo_path = 'instagram.geo'
foursquare_nyc_dyna_path = "instagram.dyna"
geo_data = pd.read_csv(foursquare_nyc_geo_path)
dyna_data = pd.read_csv(foursquare_nyc_dyna_path)
dyna_data
# Out:
#          dyna_id  type                  time  entity_id  location  \
# 0              0  traj  2011-06-15T15:33:49Z       4032       103
# 1              1  traj  2011-06-20T16:38:07Z      62898      2351
# 2              2  traj  2011-07-01T11:42:17Z      62898        30
# 3              3  traj  2011-07-01T11:45:17Z      62898        30
# 4              4  traj  2011-07-07T22:37:06Z      62898       115
# ...          ...   ...                   ...        ...       ...
# 2205789  2205789  traj  2016-11-08T03:13:52Z      36978     11082
# 2205790  2205790  traj  2016-11-08T03:21:44Z      45050      1592
# 2205791  2205791  traj  2016-11-08T03:21:54Z      36898         6
# 2205792  2205792  traj  2016-11-08T03:34:11Z       9198      9930
# 2205793  2205793  traj  2016-11-08T03:35:43Z      66591      3220
#
#                                                       text
# 0        yellow avenue fifth ave nyc newyork newyorkcit...
# 1                                                 empire x
# 2                                           looming empire
# 3                                         make like a leaf
# 4                                              light it up
# ...                                                    ...
# 2205789  we get down followus <user> photo <user> rock ...
# 2205790  post dessert course is roberta s special pizza...
# 2205791  long monday at work and this is how it wraps u...
# 2205792  king kong ain t got shit on me nyc brooklyn go...
# 2205793  song 2 of my set i was in zone whew awesome ni...
#
# [2205794 rows x 6 columns]

# %%
geo_data = geo_data.rename(columns={'geo_id': 'location'})

# %%
category_info = dyna_data.groupby(['location'], as_index = False).agg({'text':' '.join})
category_info = category_info.drop_duplicates(['location'])
poi_info = pd.merge(geo_data, category_info, on='location')
poi_info = poi_info.rename(columns={'location': 'geo_id'})
poi_info
# Out:
#        geo_id   type                             coordinates  \
# 0           0  Point  [-73.9755937700549,40.751350287303275]
# 1           1  Point  [-74.11101600275425,40.75032362105517]
# 2           2  Point  [-73.99184927390306,40.70308666000367]
# 3           3  Point  [-73.94386400613658,40.74492563587216]
# 4           4  Point  [-73.97939402346873,40.75902291504396]
# ...       ...    ...                                     ...
# 13182   13182  Point                    [-73.95899,40.72219]
# 13183   13183  Point          [-73.9172198288,40.8464492648]
# 13184   13184  Point      [-73.63412827890001,41.3496662377]
# 13185   13185  Point          [-74.0600689922,40.6023258178]
# 13186   13186  Point           [-73.81582000000002,40.86204]
#
#                                                 poi_name  \
# 0                                      chrysler building
# 1           staybridge suites times square new york city
# 2                              new york digital district
# 3      the metropolitan museum of art metropolitan mu...
# 4                       top of the rock observation deck
# ...                                                  ...
# 13182                                         schimanski
# 13183                      tmt the money team barbershop
# 13184                                  outhouse orchards
# 13185                new york public library south beach
# 13186                                      pelham bridge
manhattan il silenzio buca l aria toglie ossigeno anche a me e conosco gia a memoria questo posto e i suoi perche vivo al limite nyc triptych part one of three the view from my dentist s office i live new york city nyc skyline empirestatebuilding worldtradecenter freedomtower twin chrysler buildings metropolis new york city i love meetings in rooms with a view taken from the top of the chrysler roomwithaview nyc manhattan skyscrapers cityscape skyline chryslerbuilding chrysler empirestatebuilding peering down guest starring the ever photogenic empire state this city flying with the eagles ewaninamerica chryslerbuilding empirestatebuilding artdeco architecture hdr newyork downtown central skyhigh skyscrapers nyc chrysler building red pinksky nyc junesky manhattan bigcitylights it s summer time a 69th floor window of the chryslerbuilding empirestatebuilding view newyork landscape skyscrapers manhattan skyline artdeco architecture interior interiordecor interiordesign amazing style art grammasters3 as the sun sets over new york city the empire state building seen from the top of the chrysler icon 1 8 9 14 they don t make them like they used to view of the empirestatebuilding from the chryslerbuilding manhattan newyork nyc midtown this has to be one of the best view from a dentist s chair in the world viewfromwhereisit viewfromthetop manhatta ...

# %%
dyna_data.nunique()
# Out:
# dyna_id      2205794
# type               1
# time         2105784
# entity_id      78230
# location       13187
# text         2035871
# dtype: int64

# %%
def filter_location_checkin(df, threshold=5):
    venue_counts = df['location'].value_counts()
    filtered_venues = venue_counts[venue_counts >= threshold].index
    df = df[df['location'].isin(filtered_venues)]
    return df
dff = filter_location_checkin(dyna_data)
dff
# Out:
#          dyna_id  type                  time  entity_id  location  \
# 0              0  traj  2011-06-15T15:33:49Z       4032       103
# 1              1  traj  2011-06-20T16:38:07Z      62898      2351
# 2              2  traj  2011-07-01T11:42:17Z      62898        30
# 3              3  traj  2011-07-01T11:45:17Z      62898        30
# 4              4  traj  2011-07-07T22:37:06Z      62898       115
# ...          ...   ...                   ...        ...       ...
# 2205789  2205789  traj  2016-11-08T03:13:52Z      36978     11082
# 2205790  2205790  traj  2016-11-08T03:21:44Z      45050      1592
# 2205791  2205791  traj  2016-11-08T03:21:54Z      36898         6
# 2205792  2205792  traj  2016-11-08T03:34:11Z       9198      9930
# 2205793  2205793  traj  2016-11-08T03:35:43Z      66591      3220
#
#                                                       text
# 0        yellow avenue fifth ave nyc newyork newyorkcit...
# 1                                                 empire x
# 2                                           looming empire
# 3                                         make like a leaf
# 4                                              light it up
# ...                                                    ...
# 2205789  we get down followus <user> photo <user> rock ...
# 2205790  post dessert course is roberta s special pizza...
# 2205791  long monday at work and this is how it wraps u...
# 2205792  king kong ain t got shit on me nyc brooklyn go...
# 2205793  song 2 of my set i was in zone whew awesome ni...
#
# [2205734 rows x 6 columns]

# %%
dff.nunique()
# Out:
# dyna_id      2205734
# type               1
# time         2105727
# entity_id      78230
# location       13172
# text         2035811
# dtype: int64

# %%
#link https://dmis.korea.ac.kr/cape
import os
import pandas as pd
from datetime import datetime

output_folder = 'filtered'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
# poi_index = pd.read_csv('./poi_index.txt', sep='\t', names=['index', 'poi'])  # 应该是 index 和 poi name
word_index = pd.read_csv('./input/word_index.txt', sep='\t', names=['index', 'word'])

# poi 是 id， text_content 是由 word index 组成的句子，啊这我要给他还原吗，还是给他还原？
# 还原吧
train = pd.read_csv('./input/train.txt', sep='\t', names=['user', 'lat', 'lng', 'timestamp', 'poi', 'text_content'])
test = pd.read_csv('./input/test.txt', sep='\t', names=['user', 'lat', 'lng', 'timestamp', 'poi', 'text_content'])
validation = pd.read_csv('./input/validation.txt', sep='\t', names=['user', 'lat', 'lng', 'timestamp', 'poi', 'text_content'])
# 把 train test validation 拼接起来吧
total_check_in = pd.concat([train, test, validation])

# # 先来做 geo 表
poi_info = total_check_in.filter(items=['lat', 'lng', 'poi'])
poi_info = poi_info.groupby('location_id').mean()
poi_info.reset_index(inplace=True)
# 引入 poi name 信息
poi = poi_info.merge(poi_index, left_on='poi', right_on='index')
poi['type'] = 'Point'

# 计算 coordinates
coordinates = []
for index, row in poi.iterrows():
    coordinates.append('[{},{}]'.format(row['lng'], row['lat']))

poi['coordinates'] = coordinates
poi = poi.rename(columns={'poi_x': 'geo_id', 'poi_y': 'poi_name'})
poi = poi.drop(['lat', 'lng', 'index'])
poi = poi.reindex(columns=['geo_id', 'type', 'coordinates', 'poi_name'])
poi.to_csv(output_folder + '/instagram.geo', index=False)

# 做 usr 表
user = pd.unique(total_check_in['user'])
user = pd.DataFrame(user, columns=['usr_id'])
user.to_csv(output_folder + '/instagram.usr', index=False)

# 做 dyna 表
# 需要首先对时间做转换
time = []
text = []
# 居然有 text 为空的，建议删除 760703
total_check_in = total_check_in.dropna(axis=0, how='any')
total_check_in = total_check_in[:10]
for index, row in total_check_in.iterrows():
    date = datetime.strptime(row['timestamp'], '%Y-%m-%d %H:%M:%S')
    time.append(date.strftime('%Y-%m-%dT%H:%M:%SZ'))  # 2020-12-07T02:59:46
    word_index_list = row['text_content'].split(' ')
    words = ''
    for w in word_index_list:
        try:
            words = words + word_index.iloc[int(w)]['word'] + ' '
        except TypeError:
            words += ' '
    # 最后一个是空格
    text.append(words[:-1])

total_check_in['time'] = time
total_check_in['text'] = text
total_check_in = total_check_in.drop(['lat', 'lng', 'timestamp', 'text_content'], axis=1)
total_check_in = total_check_in.rename(columns={'poi': 'location', 'user': 'entity_id'})
total_check_in['type'] = 'traj'
total_check_in = total_check_in.sort_values(by='time')
total_check_in = total_check_in.reset_index(drop=True)
total_check_in['dyna_id'] = total_check_in.index
total_check_in = total_check_in.reindex(columns=['dyna_id', 'type', 'time', 'entity_id', 'location', 'text'])
total_check_in.to_csv(output_folder + '/instagram.dyna', index=False)
